    "cookie": COOKIE
}

courses = []
page = 1

while True:

    payload = {
        "keyword": None,
        "terms": [],
        "requirement": None,
        "subrequirement": None,
        "courseIds": None,
        "sectionIds": None,
        "requirementText": None,
        "subrequirementText": "",
        "group": None,
        "startTime": None,
        "endTime": None,
        "openSections": None,
        "subjects": [],
        "academicLevels": [],
        "courseLevels": [],
        "synonyms": [],
        "courseTypes": [],
        "topicCodes": [],
        "days": [],
        "locations": [],
        "faculty": [],
        "onlineCategories": None,
        "keywordComponents": [],
        "startDate": None,
        "endDate": None,
        "startsAtTime": None,
        "endsByTime": None,
        "pageNumber": page,
        "sortOn": "None",
        "sortDirection": "Ascending",
        "quantityPerPage": 30,
        "searchResultsView": "CatalogListing"
    }

    print("Requesting page", page)

    r = requests.post(URL, headers=headers, json=payload)

    print("Status:", r.status_code)

    if r.status_code != 200:
        print(r.text[:500])
        break

    data = r.json()

    page_courses = data.get("Courses", [])

    if not page_courses:
        break

    for c in page_courses:

        courses.append({
            "subject": c["SubjectCode"],
            "number": c["Number"],
            "title": c["Title"],
            "credits": c["MinimumCredits"],
            "description": c["Description"]
        })

    print("Collected:", len(courses))

    page += 1
    time.sleep(0.4)

df = pd.DataFrame(courses)

df.to_csv("unb_courses.csv", index=False)

print("Saved", len(df), "courses")
# Out:
# Requesting page 1
# Status: 200
# Collected: 30
# Requesting page 2
# Status: 200
# Collected: 60
# Requesting page 3
# Status: 200
# Collected: 90
# Requesting page 4
# Status: 200
# Collected: 120
# Requesting page 5
# Status: 200
# Collected: 150
# Requesting page 6
# Status: 200
# Collected: 180
# Requesting page 7
# Status: 200
# Collected: 210
# Requesting page 8
# Status: 200
# Collected: 240
# Requesting page 9
# Status: 200
# Collected: 270
# Requesting page 10
# Status: 200
# Collected: 300
# Requesting page 11
# Status: 200
# Collected: 330
# Requesting page 12
# Status: 200
# Collected: 360
# Requesting page 13
# Status: 200
# Collected: 390
# Requesting page 14
# Status: 200
# Collected: 420
# Requesting page 15
# Status: 200
# Collected: 450
# Requesting page 16
# Status: 200
# Collected: 480
# Requesting page 17
# Status: 200
# Collected: 510
# Requesting page 18
# Status: 200
# Collected: 540
# Requesting page 19
# Status: 200
# Collected: 570
# Requesting page 20
# ...

# %%
import requests
import pandas as pd
import time

#This is like a much thinner filtered web srape of SJ and in person only classes


URL = "https://selfservice.unb.ca/Student/Student/Courses/PostSearchCriteria"

TOKEN = "CfDJ8B0GSlrVWN9Dn-qVRI-h8-06loBxkXt67_XP4GpfvG9yankxMtGqGtc9WCmLzF2gFvD3UuDjebtmuOBnJOZwhV6RJzB9sUYJCCnDPJAHJ7G4NWYkcPq-F0SRvaVTRQfm-JdIafCaNlEaRAqYdrQfKFtyepdPDzhf40On9HjhGwRQZyJOUXHTlL-wzKmRZErdxw"

cElm0eufephWbB86ZYhcSXx6cKQ; studentselfservice_production_0=CfDJ8B0GSlrVWN9Dn-qVRI-h8-29Bu1xeZUouR_jOrl2AEYgTDYfZEmS12E8Xz9NrQ3ccJqm7iuPpURBdEn0KkVPo_gcWA4D_zL3aZK0jvvLhub78-ToKI4YtCaQiHRTqMId8IhQHE55yghpaBGV6HIdeeAUYX95FYPEgoL82V1f--tzwRaB6KVLWGhU2I_vyAHLBFCobHocDMH0ffNQ-uhjhxsPo0YdbaagPmS8AqbYL-NZVkE8OfyugK0EXa807EpxHIlMYQMEJGOwXX_VGlGCBFzogMQ1j6pcWJ_MOSNBwL502ZwGMGPxlwV0uXCbbSBjtPOVK5qIeR4EoZ10fY7NNEistFlWDxCZq8wE4fcDjLTF8s1zXxrQG1C2Tu-aIHu6pwFIZYZ4gNGa0kaBgCHdk25yoMfYVTU29xWenGDyJZZJfJbvENPKYiBfM4d0dYUQ8Eh3k6nw2tz5i8zIe1bYd43kffXpy99ugGkf0ESGaHcUjDLvL5QIMlalS9OIQzJYSQ15AlAVp7vxfHk2OO9KOZWVL_z3N334WuxUrfXUwu4hQ53Bx1vFmUhVmgx0Rhao12_Jc17MH-QFMIcSx_M5QGVf8PvObOc1geu7wlUrhJxxWakO8RN3GUKZQHOxn2ggrnzWVWKcI0PHtje_CSvZO6CteRk_DC4L7fL1LD_rgzVjxOdEfsJMFxnJHcrenslfDw; .ColleagueSelfServiceAntiforgery=CfDJ8B0GSlrVWN9Dn-qVRI-h8-0SMYCxwUTT2PsoP8B19vsah4NRv5pQ0kWVu12oGdjBhvdBT3zFdAWV5WPslJcAYI7oGj9ByIXd_THaj7ocjgwAgmWI11y-4576ofJ9HBh07LaSlifD7pXk8MUrXt1_CAw"

headers = {
    "accept": "application/json, text/javascript, */*; q=0.01",
    "content-type": "application/json, charset=UTF-8",
    "origin": "https://selfservice.unb.ca",
    "referer": "https://selfservice.unb.ca/Student/Student/Courses/Search",
    "user-agent": "Mozilla/5.0",
    "x-requested-with": "XMLHttpRequest",
    "__requestverificationtoken": TOKEN,
    "__isguestuser": "false",
    "cookie": COOKIE
}

courses = []
page = 1

while True:

    payload = {
    "keyword": None,
    "terms": [],
    "subjects": [],
    "academicLevels": [],
    "courseLevels": [],
    "locations": ["SJ"],   # UNB Saint John only
    "onlineCategories": [],  # exclude online
    "pageNumber": page,
    "quantityPerPage": 30,
    "sortOn": "None",
    "sortDirection": "Ascending",
    "searchResultsView": "CatalogListing"
}

    print("Requesting page", page)

    r = requests.post(URL, headers=headers, json=payload)

    print("Status:", r.status_code)

    if r.status_code != 200:
        print(r.text[:500])
        break

    data = r.json()

    page_courses = data.get("Courses", [])

    if not page_courses:
        break

    for c in page_courses:

        courses.append({
            "subject": c["SubjectCode"],
            "number": c["Number"],
            "title": c["Title"],
            "credits": c["MinimumCredits"],
            "description": c["Description"]
        })

    print("Collected:", len(courses))

    page += 1
    time.sleep(0.4)

df = pd.DataFrame(courses)

df.to_csv("unb_courses.csv", index=False)

print("Saved", len(df), "courses")
